# %%
# %pip install python-dotenv
# %pip install pandas
# Out:
# Requirement already satisfied: python-dotenv in c:\users\hp\desktop\projects 2025\autoexpense\venv\lib\site-packages (1.0.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.3; however, version 25.0.1 is available.
# You should consider upgrading via the 'c:\Users\hp\Desktop\PROJECTS 2025\AutoExpense\venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: pandas in c:\users\hp\desktop\projects 2025\autoexpense\venv\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\hp\desktop\projects 2025\autoexpense\venv\lib\site-packages (from pandas) (2.0.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\desktop\projects 2025\autoexpense\venv\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\desktop\projects 2025\autoexpense\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\desktop\projects 2025\autoexpense\venv\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\hp\desktop\projects 2025\autoexpense\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# WARNING: You are using pip version 21.1.3; however, version 25.0.1 is available.
# You should consider upgrading via the 'c:\Users\hp\Desktop\PROJECTS 2025\AutoExpense\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# **Data Loading/Importing Google Sheets**

# %%
##Loading the required variables from the .env file

from dotenv import load_dotenv
import os

# Load environment variables from a .env file
load_dotenv()

# Access the environment variables
sheet_id = os.getenv('SHEET_ID')

# %%
# %pwd
# Out:
# 'c:\\Users\\hp\\Desktop\\PROJECTS 2025\\AutoExpense\\Experiments'

# %%
# %cd ..
# Out:
# c:\Users\hp\Desktop\PROJECTS 2025\AutoExpense
# c:\Users\hp\Desktop\PROJECTS 2025\AutoExpense\venv\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import gspread
from google.oauth2.service_account import Credentials

# Define the scope
scope = ["https://spreadsheets.google.com/feeds", "https://www.googleapis.com/auth/drive"]

# Add credentials to the account
creds = Credentials.from_service_account_file('credentials.json', scopes=scope)

# Authorize the clientsheet 
client = gspread.authorize(creds)

# Get the sheet by name
sheet = client.open_by_key(sheet_id).worksheet("master_test")

# Print the sheet data
data = sheet.get_all_records()
data
# Out:
# [{'Date': '21/06/2022',
#   'Month': 'June',
#   'Name of expense': 'Lotion',
#   'Type of expense': 'Accessories',
#   'Amount': 195,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '21/06/2022',
#   'Month': 'June',
#   'Name of expense': 'Smokies',
#   'Type of expense': 'Thrills',
#   'Amount': 30,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '22/06/2022',
#   'Month': 'June',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 100,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '22/06/2022',
#   'Month': 'June',
#   'Name of expense': 'ID application fee',
#   'Type of expense': 'Utilities',
#   'Amount': 100,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '22/06/2022',
#   'Month': 'June',
#   'Name of expense': 'Eggs',
#   'Type of expense': 'Food',
#   'Amount': 30,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '22/06/2022',
#   'Month': 'June',
#   'Name of expense': 'Printing Fee',
#   'Type of expense': 'Petty Cash',
#   'Amount': 5,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '22/06/2022',
#   'Month': 'June',
#   'Name of expense': 'Toilet',
#   'Type of expense': 'Petty Cash',
#   'Amount': 10,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '22/06/2022',
#   'Month': 'June',
#   'Name of expense': 'KDF',
#   'Type of expense': 'Thrills',
#   'Amount': 20,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '22/06/2022',
#   'Month': 'June',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 230,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '24/06/2022',
#   'Month': 'June',
#   'Name of expense': 'Suppository',
#   'Type of expense': 'Medicine',
#   'Amount': 180,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '24/06/2022',
#   'Month': 'June',
#   'Name of expense': 'Mandazi',
#   'Type of expense': 'Food',
#   'Amount': 30,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '24/06/2022',
#   'Month': 'June',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 200,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '24/06/2022',
#   'Month': 'June',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 270,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '24/06/2022',
#   'Month': 'June',
#   'Name of expense': 'Spotify',
#   'Type of expense': 'Utilities',
#   'Amount': 149,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '25/06/2022',
#   'Month': 'June',
#   'Name of expense': 'Buscopan',
#   'Type of expense': 'Medicine',
#   'Amount': 200,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '25/06/2022',
#   'Month': 'June',
#   'Name of expense': 'Mzish',
#   'Type of expense': 'Entertainment',
#   'Amount': 375,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '25/06/2022',
#   'Month': 'June',
#   'Name of expense': 'Cakes',
#   'Type of expense': 'Thrills',
#   'Amount': 90,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '25/06/2022',
#   'Month': 'June',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 180,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '26/06/2022',
#   'Month': 'June',
#   'Name of expense': 'KFC',
#   'Type of expense': 'Entertainment',
#   'Amount': 449,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '26/06/2022',
#   'Month': 'June',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 150,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '27/06/2022',
#   'Month': 'June',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 200,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '27/06/2022',
#   'Month': 'June',
#   'Name of expense': 'Eggs',
#   'Type of expense': 'Food',
#   'Amount': 45,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '28/06/2022',
#   'Month': 'June',
#   'Name of expense': 'Mandazi',
#   'Type of expense': 'Food',
#   'Amount': 30,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '28/06/2022',
#   'Month': 'June',
#   'Name of expense': 'Smokies',
#   'Type of expense': 'Thrills',
#   'Amount': 30,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '28/06/2022',
#   'Month': 'June',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 120,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '29/06/2022',
#   'Month': 'June',
#   'Name of expense': 'A Pair of shorts',
#   'Type of expense': 'Clothes',
#   'Amount': 200,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '29/06/2022',
#   'Month': 'June',
#   'Name of expense': 'Shawarma',
#   'Type of expense': 'Thrills',
#   'Amount': 250,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '30/06/2022',
#   'Month': 'June',
#   'Name of expense': 'Eggs',
#   'Type of expense': 'Food',
#   'Amount': 45,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '01/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 100,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '01/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Tots',
#   'Type of expense': 'Entertainment',
#   'Amount': 3070,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '01/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Fresh Chewing Gums',
#   'Type of expense': 'Thrills',
#   'Amount': 20,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '01/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 80,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '02/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 200,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '02/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Mandazi',
#   'Type of expense': 'Food',
#   'Amount': 30,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '02/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Smocha',
#   'Type of expense': 'Thrills',
#   'Amount': 100,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '02/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 250,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '03/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Galitos Juice',
#   'Type of expense': 'Thrills',
#   'Amount': 195,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '03/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 180,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '07/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 200,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '07/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Bluetooth Speaker',
#   'Type of expense': 'Accessories',
#   'Amount': 872,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '07/07/2022',
#   'Month': 'July',
#   'Name of expense': 'NHIF',
#   'Type of expense': 'Utilities',
#   'Amount': 500,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '08/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Chips',
#   'Type of expense': 'Thrills',
#   'Amount': 270,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '10/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 200,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '10/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Clothes',
#   'Type of expense': 'Clothes',
#   'Amount': 500,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '10/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Shawarma',
#   'Type of expense': 'Thrills',
#   'Amount': 600,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '10/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Uber',
#   'Type of expense': 'Transport',
#   'Amount': 560,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '13/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Key Cutting',
#   'Type of expense': 'Household Items',
#   'Amount': 150,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '13/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Chapati',
#   'Type of expense': 'Thrills',
#   'Amount': 20,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '13/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Smokies',
#   'Type of expense': 'Thrills',
#   'Amount': 30,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '14/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Toilet',
#   'Type of expense': 'Petty Cash',
#   'Amount': 10,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '14/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Park Fees',
#   'Type of expense': 'Entertainment',
#   'Amount': 270,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '14/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 150,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '14/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Chicken Inn',
#   'Type of expense': 'Thrills',
#   'Amount': 690,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '14/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 380,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '15/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 100,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '15/07/2022',
#   'Month': 'July',
#   'Name of expense': 'KFC',
#   'Type of expense': 'Thrills',
#   'Amount': 639,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '18/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Wooven Bag',
#   'Type of expense': 'Petty Cash',
#   'Amount': 15,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '18/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 100,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '18/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Haircut',
#   'Type of expense': 'Accessories',
#   'Amount': 150,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '18/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Face Scrub',
#   'Type of expense': 'Household Items',
#   'Amount': 477,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '18/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Salt',
#   'Type of expense': 'Household Items',
#   'Amount': 69,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '19/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Toilet',
#   'Type of expense': 'Petty Cash',
#   'Amount': 10,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '19/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 300,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '19/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 360,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '20/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Bitez',
#   'Type of expense': 'Petty Cash',
#   'Amount': 50,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '22/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Toilet',
#   'Type of expense': 'Petty Cash',
#   'Amount': 10,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '22/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Sweets',
#   'Type of expense': 'Petty Cash',
#   'Amount': 10,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '22/07/2022',
#   'Month': 'July',
#   'Name of expense': 'MJ',
#   'Type of expense': 'Entertainment',
#   'Amount': 250,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '22/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 100,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '22/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 180,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '23/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Gibs',
#   'Type of expense': 'Entertainment',
#   'Amount': 949,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '23/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Sprite',
#   'Type of expense': 'Entertainment',
#   'Amount': 120,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '23/07/2022',
#   'Month': 'July',
#   'Name of expense': 'BlackIce',
#   'Type of expense': 'Entertainment',
#   'Amount': 149,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '23/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Eggs',
#   'Type of expense': 'Food',
#   'Amount': 90,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '23/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Smokies',
#   'Type of expense': 'Thrills',
#   'Amount': 35,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '23/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 70,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '24/07/2022',
#   'Month': 'July',
#   'Name of expense': 'KFC',
#   'Type of expense': 'Thrills',
#   'Amount': 639,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '26/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Pilipili',
#   'Type of expense': 'Food',
#   'Amount': 5,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '26/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Bread',
#   'Type of expense': 'Food',
#   'Amount': 60,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '26/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Mandazi',
#   'Type of expense': 'Thrills',
#   'Amount': 30,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '27/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Eggs',
#   'Type of expense': 'Food',
#   'Amount': 90,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '28/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Printing Fee',
#   'Type of expense': 'Petty Cash',
#   'Amount': 262,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '28/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Toilet',
#   'Type of expense': 'Petty Cash',
#   'Amount': 20,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '28/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Galitos Chicken + Water',
#   'Type of expense': 'Food',
#   'Amount': 790,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '28/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Soda',
#   'Type of expense': 'Thrills',
#   'Amount': 70,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '28/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 310,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '28/07/2022',
#   'Month': 'July',
#   'Name of expense': 'NSSF',
#   'Type of expense': 'Utilities',
#   'Amount': 25,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '30/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Bounty',
#   'Type of expense': 'Thrills',
#   'Amount': 130,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '31/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Cabbage',
#   'Type of expense': 'Food',
#   'Amount': 10,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '31/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Water',
#   'Type of expense': 'Food',
#   'Amount': 80,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '31/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Purple Chewing Gum',
#   'Type of expense': 'Thrills',
#   'Amount': 50,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '31/07/2022',
#   'Month': 'July',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 150,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '01/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Printing Fee',
#   'Type of expense': 'Petty Cash',
#   'Amount': 30,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '01/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Rings',
#   'Type of expense': 'Clothes',
#   'Amount': 200,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '01/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Comb',
#   'Type of expense': 'Accessories',
#   'Amount': 95,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '01/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Spray Bottle',
#   'Type of expense': 'Accessories',
#   'Amount': 140,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '01/08/2022',
#   'Month': 'August',
#   'Name of expense': 'NHIF application fee',
#   'Type of expense': 'Utilities',
#   'Amount': 200,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '01/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 100,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '01/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 160,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '02/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Printing Fee',
#   'Type of expense': 'Petty Cash',
#   'Amount': 65,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '02/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 100,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '02/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Offering',
#   'Type of expense': 'Goodwill',
#   'Amount': 50,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '02/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Candy',
#   'Type of expense': 'Thrills',
#   'Amount': 150,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '03/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Food Handlers Cert',
#   'Type of expense': 'Utilities',
#   'Amount': 1000,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '03/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Toilet',
#   'Type of expense': 'Petty Cash',
#   'Amount': 20,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '03/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Goodwill',
#   'Type of expense': 'Goodwill',
#   'Amount': 120,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '03/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Rings',
#   'Type of expense': 'Clothes',
#   'Amount': 200,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '03/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Chicken Inn',
#   'Type of expense': 'Entertainment',
#   'Amount': 965,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '03/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Smokies',
#   'Type of expense': 'Thrills',
#   'Amount': 70,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '03/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 160,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '04/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Scanning Fee',
#   'Type of expense': 'Petty Cash',
#   'Amount': 40,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '04/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Toilet',
#   'Type of expense': 'Petty Cash',
#   'Amount': 10,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '04/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 20,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '04/08/2022',
#   'Month': 'August',
#   'Name of expense': 'KRA fee',
#   'Type of expense': 'Utilities',
#   'Amount': 1000,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '04/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 200,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '04/08/2022',
#   'Month': 'August',
#   'Name of expense': 'S.Black Ice',
#   'Type of expense': 'Thrills',
#   'Amount': 180,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '04/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Smokies',
#   'Type of expense': 'Thrills',
#   'Amount': 70,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '05/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Eggs',
#   'Type of expense': 'Food',
#   'Amount': 90,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '05/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Candy',
#   'Type of expense': 'Thrills',
#   'Amount': 360,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '05/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Uber',
#   'Type of expense': 'Transport',
#   'Amount': 590,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '05/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 30,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '08/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Pilipili',
#   'Type of expense': 'Food',
#   'Amount': 5,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '08/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Oranges',
#   'Type of expense': 'Food',
#   'Amount': 20,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '09/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Savings',
#   'Type of expense': 'Savings',
#   'Amount': 990,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '10/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 100,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '10/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Savings',
#   'Type of expense': 'Savings',
#   'Amount': 1150,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '10/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Eggs',
#   'Type of expense': 'Food',
#   'Amount': 90,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '10/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Probiotics',
#   'Type of expense': 'Food',
#   'Amount': 129,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '10/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Jik Colours',
#   'Type of expense': 'Household Items',
#   'Amount': 95,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '10/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Pepper',
#   'Type of expense': 'Food',
#   'Amount': 130,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '10/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Indomie',
#   'Type of expense': 'Food',
#   'Amount': 119,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '10/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Ice Cream',
#   'Type of expense': 'Thrills',
#   'Amount': 140,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '10/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Chocolate',
#   'Type of expense': 'Thrills',
#   'Amount': 70,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '10/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Gum',
#   'Type of expense': 'Thrills',
#   'Amount': 60,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '10/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 80,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '11/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 100,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '12/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Printing Fee',
#   'Type of expense': 'Petty Cash',
#   'Amount': 30,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '12/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Water',
#   'Type of expense': 'Food',
#   'Amount': 40,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '12/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Gloves',
#   'Type of expense': 'Clothes',
#   'Amount': 250,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '12/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 200,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '12/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Tissue',
#   'Type of expense': 'Household Items',
#   'Amount': 55,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '12/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Best',
#   'Type of expense': 'Entertainment',
#   'Amount': 770,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '12/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Haircut',
#   'Type of expense': 'Accessories',
#   'Amount': 150,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '12/08/2022',
#   'Month': 'August',
#   'Name of expense': 'KFC',
#   'Type of expense': 'Entertainment',
#   'Amount': 649,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '12/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Smokies',
#   'Type of expense': 'Thrills',
#   'Amount': 70,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '12/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Gum',
#   'Type of expense': 'Thrills',
#   'Amount': 24,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '12/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 180,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '13/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Drink',
#   'Type of expense': 'Entertainment',
#   'Amount': 225,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '13/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Passport',
#   'Type of expense': 'Utilities',
#   'Amount': 600,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '13/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 240,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '14/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Printing Fee',
#   'Type of expense': 'Petty Cash',
#   'Amount': 40,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '14/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Bread',
#   'Type of expense': 'Food',
#   'Amount': 60,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '14/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Offering',
#   'Type of expense': 'Goodwill',
#   'Amount': 50,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '14/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Beans',
#   'Type of expense': 'Food',
#   'Amount': 245,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '14/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Glue',
#   'Type of expense': 'Household Items',
#   'Amount': 40,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '14/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Vegetables',
#   'Type of expense': 'Food',
#   'Amount': 125,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '14/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 200,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '14/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Eggs',
#   'Type of expense': 'Food',
#   'Amount': 90,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '14/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Wooven Bag',
#   'Type of expense': 'Thrills',
#   'Amount': 10,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '14/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 100,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '15/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Choo',
#   'Type of expense': 'Petty Cash',
#   'Amount': 10,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '15/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 100,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '15/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 490,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '16/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Choo',
#   'Type of expense': 'Petty Cash',
#   'Amount': 10,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '16/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Vegetables',
#   'Type of expense': 'Food',
#   'Amount': 100,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '16/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Eggs',
#   'Type of expense': 'Food',
#   'Amount': 90,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '16/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 600,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '17/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Choo',
#   'Type of expense': 'Petty Cash',
#   'Amount': 20,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '17/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 520,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '18/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Choo',
#   'Type of expense': 'Petty Cash',
#   'Amount': 10,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '18/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Chocolate',
#   'Type of expense': 'Thrills',
#   'Amount': 220,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '18/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Candy',
#   'Type of expense': 'Petty Cash',
#   'Amount': 160,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '18/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 100,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '18/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Peanut Butter',
#   'Type of expense': 'Food',
#   'Amount': 180,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '18/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Jam',
#   'Type of expense': 'Food',
#   'Amount': 155,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '18/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Battery',
#   'Type of expense': 'Household Items',
#   'Amount': 405,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '18/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 370,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '19/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Choo',
#   'Type of expense': 'Petty Cash',
#   'Amount': 30,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '19/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Water',
#   'Type of expense': 'Food',
#   'Amount': 50,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '19/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Ngumuu',
#   'Type of expense': 'Food',
#   'Amount': 30,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '19/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Chapati',
#   'Type of expense': 'Food',
#   'Amount': 100,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '19/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Soda',
#   'Type of expense': 'Food',
#   'Amount': 105,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '19/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 600,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '20/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Choo',
#   'Type of expense': 'Petty Cash',
#   'Amount': 10,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '20/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Yorghurt/PinPop',
#   'Type of expense': 'Thrills',
#   'Amount': 115,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '20/08/2022',
#   'Month': 'August',
#   'Name of expense': 'KFC',
#   'Type of expense': 'Entertainment',
#   'Amount': 859,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '20/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 110,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '20/08/2022',
#   'Month': 'August',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 310,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '12/11/2022',
#   'Month': 'November',
#   'Name of expense': 'KFC',
#   'Type of expense': 'Thrills',
#   'Amount': 650,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '14/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Printing',
#   'Type of expense': 'Petty Cash',
#   'Amount': 30,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '14/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Shopping',
#   'Type of expense': 'Shopping',
#   'Amount': 265,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '14/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Naivas Pilau',
#   'Type of expense': 'Food',
#   'Amount': 356,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '14/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Good will',
#   'Type of expense': 'Goodwill',
#   'Amount': 100,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '14/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Earphones',
#   'Type of expense': 'Accessories',
#   'Amount': 250,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '15/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Mandazi',
#   'Type of expense': 'Food',
#   'Amount': 80,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '15/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Eggs',
#   'Type of expense': 'Food',
#   'Amount': 90,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '15/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Berry',
#   'Type of expense': 'Thrills',
#   'Amount': 90,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '15/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Uber',
#   'Type of expense': 'Transport',
#   'Amount': 1150,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '15/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Water Bill',
#   'Type of expense': 'Utilities',
#   'Amount': 400,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '16/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Mandazi',
#   'Type of expense': 'Food',
#   'Amount': 40,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '16/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Socks',
#   'Type of expense': 'Clothes',
#   'Amount': 240,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '17/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Mandazi',
#   'Type of expense': 'Food',
#   'Amount': 50,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '17/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 300,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '17/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 60,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '18/11/2022',
#   'Month': 'November',
#   'Name of expense': 'T/or Dare Cards',
#   'Type of expense': 'Entertainment',
#   'Amount': 420,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '18/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Chips',
#   'Type of expense': 'Thrills',
#   'Amount': 400,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '18/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Mombasa Trip',
#   'Type of expense': 'Vacation',
#   'Amount': 1417,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '19/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Perfume',
#   'Type of expense': 'Accessories',
#   'Amount': 899,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '19/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Spotify',
#   'Type of expense': 'Utilities',
#   'Amount': 150,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '21/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 100,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '22/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Sweets',
#   'Type of expense': 'Thrills',
#   'Amount': 30,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '23/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Smocha',
#   'Type of expense': 'Thrills',
#   'Amount': 185,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '23/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Wifi',
#   'Type of expense': 'Utilities',
#   'Amount': 4200,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '25/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Carrier Bag',
#   'Type of expense': 'Petty Cash',
#   'Amount': 10,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '25/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Mandazi',
#   'Type of expense': 'Food',
#   'Amount': 50,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '25/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Earbuds',
#   'Type of expense': 'Accessories',
#   'Amount': 650,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '25/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Miwa',
#   'Type of expense': 'Thrills',
#   'Amount': 50,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '25/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Smokie',
#   'Type of expense': 'Thrills',
#   'Amount': 35,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '25/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Juice',
#   'Type of expense': 'Thrills',
#   'Amount': 100,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '25/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 100,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '26/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Eggs',
#   'Type of expense': 'Food',
#   'Amount': 60,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '26/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Fresh',
#   'Type of expense': 'Thrills',
#   'Amount': 10,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '26/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Bitez',
#   'Type of expense': 'Thrills',
#   'Amount': 20,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '27/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Shopping',
#   'Type of expense': 'Shopping',
#   'Amount': 699,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '27/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Go fruit',
#   'Type of expense': 'Food',
#   'Amount': 123,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '27/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 50,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '28/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Sunnies',
#   'Type of expense': 'Accessories',
#   'Amount': 400,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '28/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 200,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '28/11/2022',
#   'Month': 'November',
#   'Name of expense': 'KFC',
#   'Type of expense': 'Food',
#   'Amount': 604,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '28/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 70,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '28/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Return SGR',
#   'Type of expense': 'Vacation',
#   'Amount': 2000,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '29/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Chips',
#   'Type of expense': 'Food',
#   'Amount': 150,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '29/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Tinah Debt',
#   'Type of expense': 'Debt',
#   'Amount': 1000,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '29/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Uber',
#   'Type of expense': 'Transport',
#   'Amount': 220,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '29/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Uber',
#   'Type of expense': 'Transport',
#   'Amount': 499,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '30/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Toilet',
#   'Type of expense': 'Petty Cash',
#   'Amount': 15,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '30/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 100,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '30/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Haircut',
#   'Type of expense': 'Accessories',
#   'Amount': 250,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '30/11/2022',
#   'Month': 'November',
#   'Name of expense': 'Doughnut',
#   'Type of expense': 'Thrills',
#   'Amount': 100,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '01/12/2022',
#   'Month': 'December',
#   'Name of expense': 'Assorted drugs',
#   'Type of expense': 'Medicine',
#   'Amount': 625,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '01/12/2022',
#   'Month': 'December',
#   'Name of expense': 'Masks',
#   'Type of expense': 'Petty Cash',
#   'Amount': 40,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '01/12/2022',
#   'Month': 'December',
#   'Name of expense': 'Galitos',
#   'Type of expense': 'Food',
#   'Amount': 780,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '01/12/2022',
#   'Month': 'December',
#   'Name of expense': 'Hot Chocolate',
#   'Type of expense': 'Entertainment',
#   'Amount': 150,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '01/12/2022',
#   'Month': 'December',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 200,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '01/12/2022',
#   'Month': 'December',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 230,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '01/12/2022',
#   'Month': 'December',
#   'Name of expense': 'Uber',
#   'Type of expense': 'Transport',
#   'Amount': 460,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '01/12/2022',
#   'Month': 'December',
#   'Name of expense': 'Fetherlite',
#   'Type of expense': 'Vacation',
#   'Amount': 400,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '01/12/2022',
#   'Month': 'December',
#   'Name of expense': 'Shopping',
#   'Type of expense': 'Vacation',
#   'Amount': 296,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '01/12/2022',
#   'Month': 'December',
#   'Name of expense': 'Shopping',
#   'Type of expense': 'Vacation',
#   'Amount': 2870,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '01/12/2022',
#   'Month': 'December',
#   'Name of expense': 'Mombasa Trip',
#   'Type of expense': 'Vacation',
#   'Amount': 5760,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '01/12/2022',
#   'Month': 'December',
#   'Name of expense': 'Transfers',
#   'Type of expense': 'Vacation',
#   'Amount': 2314,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Thursday'},
#  {'Date': '02/12/2022',
#   'Month': 'December',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 100,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '02/12/2022',
#   'Month': 'December',
#   'Name of expense': 'Java',
#   'Type of expense': 'Entertainment',
#   'Amount': 2020,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '02/12/2022',
#   'Month': 'December',
#   'Name of expense': 'Netflix',
#   'Type of expense': 'Utilities',
#   'Amount': 1100,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '02/12/2022',
#   'Month': 'December',
#   'Name of expense': 'Lichtaus Water',
#   'Type of expense': 'Vacation',
#   'Amount': 300,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Friday'},
#  {'Date': '03/12/2022',
#   'Month': 'December',
#   'Name of expense': 'Tip',
#   'Type of expense': 'Goodwill',
#   'Amount': 100,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Saturday'},
#  {'Date': '04/12/2022',
#   'Month': 'December',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 100,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '04/12/2022',
#   'Month': 'December',
#   'Name of expense': 'Uber',
#   'Type of expense': 'Transport',
#   'Amount': 265,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '04/12/2022',
#   'Month': 'December',
#   'Name of expense': 'Miscellaneous',
#   'Type of expense': 'Vacation',
#   'Amount': 1391,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '04/12/2022',
#   'Month': 'December',
#   'Name of expense': 'SGR Lunch',
#   'Type of expense': 'Vacation',
#   'Amount': 600,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Sunday'},
#  {'Date': '05/12/2022',
#   'Month': 'December',
#   'Name of expense': 'Toothbrush',
#   'Type of expense': 'Household Items',
#   'Amount': 35,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Monday'},
#  {'Date': '06/12/2022',
#   'Month': 'December',
#   'Name of expense': 'PinPop',
#   'Type of expense': 'Thrills',
#   'Amount': 10,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Tuesday'},
#  {'Date': '07/12/2022',
#   'Month': 'December',
#   'Name of expense': 'PinPop',
#   'Type of expense': 'Thrills',
#   'Amount': 10,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '07/12/2022',
#   'Month': 'December',
#   'Name of expense': 'Berry',
#   'Type of expense': 'Thrills',
#   'Amount': 40,
#   'Comments': '',
#   'Year': 2022,
#   'Day': 'Wednesday'},
#  {'Date': '11/12/2022',
#   'Month': 'December',
#   'Name of expense': 'Egg',
#   'Type of expense': 'Food',
# ...
#   'Amount': 1416,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Friday'},
#  {'Date': '17/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Snacks',
#   'Type of expense': 'Thrills',
#   'Amount': 110,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Saturday'},
#  {'Date': '17/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 180,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Saturday'},
#  {'Date': '17/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Fathers Day Pillow Case',
#   'Type of expense': 'Household Items',
#   'Amount': 700,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Saturday'},
#  {'Date': '17/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Hoodie',
#   'Type of expense': 'Clothes',
#   'Amount': 406,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Saturday'},
#  {'Date': '17/06/2023',
#   'Month': 'June',
#   'Name of expense': 'C2B[STC]',
#   'Type of expense': 'Withdrawals',
#   'Amount': 50,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Saturday'},
#  {'Date': '17/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Java',
#   'Type of expense': 'Food',
#   'Amount': 630,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Saturday'},
#  {'Date': '17/06/2023',
#   'Month': 'June',
#   'Name of expense': 'B2C[Mpesa]',
#   'Type of expense': 'Withdrawals',
#   'Amount': 820,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Saturday'},
#  {'Date': '18/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Ngumuu/Smokie',
#   'Type of expense': 'Thrills',
#   'Amount': 90,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Sunday'},
#  {'Date': '18/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Fixing clothes',
#   'Type of expense': 'Clothes',
#   'Amount': 130,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Sunday'},
#  {'Date': '18/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 200,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Sunday'},
#  {'Date': '19/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Snacks',
#   'Type of expense': 'Thrills',
#   'Amount': 165,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Monday'},
#  {'Date': '19/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 200,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Monday'},
#  {'Date': '20/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 160,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Tuesday'},
#  {'Date': '20/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 50,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Tuesday'},
#  {'Date': '21/06/2023',
#   'Month': 'June',
#   'Name of expense': 'PK',
#   'Type of expense': 'Thrills',
#   'Amount': 30,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Wednesday'},
#  {'Date': '21/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Smokie',
#   'Type of expense': 'Thrills',
#   'Amount': 60,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Wednesday'},
#  {'Date': '21/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 310,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Wednesday'},
#  {'Date': '21/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Uber',
#   'Type of expense': 'Transport',
#   'Amount': 602,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Wednesday'},
#  {'Date': '21/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Breakfast',
#   'Type of expense': 'Food',
#   'Amount': 80,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Wednesday'},
#  {'Date': '21/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 200,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Wednesday'},
#  {'Date': '21/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Chicken Inn',
#   'Type of expense': 'Food',
#   'Amount': 710,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Wednesday'},
#  {'Date': '23/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Blood test',
#   'Type of expense': 'Medicine',
#   'Amount': 1500,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Friday'},
#  {'Date': '23/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Savings',
#   'Type of expense': 'Savings',
#   'Amount': 10000,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Friday'},
#  {'Date': '23/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 120,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Friday'},
#  {'Date': '23/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Uber',
#   'Type of expense': 'Transport',
#   'Amount': 542,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Friday'},
#  {'Date': '23/06/2023',
#   'Month': 'June',
#   'Name of expense': 'B2C[mum]',
#   'Type of expense': 'Utilities',
#   'Amount': 12076,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Friday'},
#  {'Date': '23/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Juice',
#   'Type of expense': 'Food',
#   'Amount': 130,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Friday'},
#  {'Date': '23/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Breakfast',
#   'Type of expense': 'Food',
#   'Amount': 40,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Friday'},
#  {'Date': '23/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 500,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Friday'},
#  {'Date': '23/06/2023',
#   'Month': 'June',
#   'Name of expense': 'C2B',
#   'Type of expense': 'Withdrawals',
#   'Amount': 5033,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Friday'},
#  {'Date': '23/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Disparity',
#   'Type of expense': 'Disparity',
#   'Amount': 16,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Friday'},
#  {'Date': '23/06/2023',
#   'Month': 'June',
#   'Name of expense': 'B2B[standard]',
#   'Type of expense': 'Withdrawals',
#   'Amount': 21863,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Friday'},
#  {'Date': '23/06/2023',
#   'Month': 'June',
#   'Name of expense': 'B2C[me]',
#   'Type of expense': 'Withdrawals',
#   'Amount': 25078,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Friday'},
#  {'Date': '23/06/2023',
#   'Month': 'June',
#   'Name of expense': 'B2C[me]',
#   'Type of expense': 'Withdrawals',
#   'Amount': 5500,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Friday'},
#  {'Date': '24/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 180,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Saturday'},
#  {'Date': '24/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Sandwich',
#   'Type of expense': 'Food',
#   'Amount': 630,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Saturday'},
#  {'Date': '24/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Goodwill',
#   'Type of expense': 'Goodwill',
#   'Amount': 2526,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Saturday'},
#  {'Date': '25/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Jik',
#   'Type of expense': 'Shopping',
#   'Amount': 170,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Sunday'},
#  {'Date': '25/06/2023',
#   'Month': 'June',
#   'Name of expense': 'SmochaSoda',
#   'Type of expense': 'Thrills',
#   'Amount': 130,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Sunday'},
#  {'Date': '25/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 220,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Sunday'},
#  {'Date': '25/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Khakis',
#   'Type of expense': 'Clothes',
#   'Amount': 1200,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Sunday'},
#  {'Date': '25/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Sports shoes',
#   'Type of expense': 'Clothes',
#   'Amount': 1422,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Sunday'},
#  {'Date': '25/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Breakfast',
#   'Type of expense': 'Food',
#   'Amount': 60,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Sunday'},
#  {'Date': '25/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Vegetables',
#   'Type of expense': 'Food',
#   'Amount': 20,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Sunday'},
#  {'Date': '25/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Withdrawal Costs',
#   'Type of expense': 'Withdrawal Costs',
#   'Amount': 28,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Sunday'},
#  {'Date': '26/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Ice cream',
#   'Type of expense': 'Thrills',
#   'Amount': 200,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Monday'},
#  {'Date': '26/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 180,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Monday'},
#  {'Date': '26/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 100,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Monday'},
#  {'Date': '26/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Earbuds',
#   'Type of expense': 'Accessories',
#   'Amount': 1900,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Monday'},
#  {'Date': '26/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 500,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Monday'},
#  {'Date': '26/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Pilau',
#   'Type of expense': 'Food',
#   'Amount': 440,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Monday'},
#  {'Date': '26/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Drinks',
#   'Type of expense': 'Entertainment',
#   'Amount': 610,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Monday'},
#  {'Date': '26/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Airbnb',
#   'Type of expense': 'Entertainment',
#   'Amount': 2588,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Monday'},
#  {'Date': '27/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 150,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Tuesday'},
#  {'Date': '27/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Airbnb',
#   'Type of expense': 'Entertainment',
#   'Amount': 2590,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Tuesday'},
#  {'Date': '27/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Drinks',
#   'Type of expense': 'Entertainment',
#   'Amount': 680,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Tuesday'},
#  {'Date': '28/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Shopping',
#   'Type of expense': 'Thrills',
#   'Amount': 245,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Wednesday'},
#  {'Date': '28/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Uber',
#   'Type of expense': 'Transport',
#   'Amount': 822,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Wednesday'},
#  {'Date': '28/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 280,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Wednesday'},
#  {'Date': '28/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Breakfast',
#   'Type of expense': 'Food',
#   'Amount': 100,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Wednesday'},
#  {'Date': '28/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Toothbrush',
#   'Type of expense': 'Household Items',
#   'Amount': 240,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Wednesday'},
#  {'Date': '28/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Galitos',
#   'Type of expense': 'Food',
#   'Amount': 865,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Wednesday'},
#  {'Date': '29/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Home shopping',
#   'Type of expense': 'Shopping',
#   'Amount': 1347,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Thursday'},
#  {'Date': '29/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 170,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Thursday'},
#  {'Date': '29/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Mattress',
#   'Type of expense': 'Household Items',
#   'Amount': 8836,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Thursday'},
#  {'Date': '29/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Chapati',
#   'Type of expense': 'Food',
#   'Amount': 60,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Thursday'},
#  {'Date': '29/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Disparity',
#   'Type of expense': 'Disparity',
#   'Amount': 399,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Thursday'},
#  {'Date': '29/06/2023',
#   'Month': 'June',
#   'Name of expense': 'B2C[me]',
#   'Type of expense': 'Withdrawals',
#   'Amount': 8966,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Thursday'},
#  {'Date': '30/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Food',
#   'Type of expense': 'Thrills',
#   'Amount': 632,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Friday'},
#  {'Date': '30/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Yoghurt',
#   'Type of expense': 'Thrills',
#   'Amount': 90,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Friday'},
#  {'Date': '30/06/2023',
#   'Month': 'June',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 100,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Friday'},
#  {'Date': '01/07/2023',
#   'Month': 'July',
#   'Name of expense': 'Clothes Repair',
#   'Type of expense': 'Clothes',
#   'Amount': 170,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Saturday'},
#  {'Date': '01/07/2023',
#   'Month': 'July',
#   'Name of expense': 'Printing Fee',
#   'Type of expense': 'Petty Cash',
#   'Amount': 210,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Saturday'},
#  {'Date': '01/07/2023',
#   'Month': 'July',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 140,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Saturday'},
#  {'Date': '01/07/2023',
#   'Month': 'July',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 600,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Saturday'},
#  {'Date': '01/07/2023',
#   'Month': 'July',
#   'Name of expense': 'Uber',
#   'Type of expense': 'Transport',
#   'Amount': 256,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Saturday'},
#  {'Date': '01/07/2023',
#   'Month': 'July',
#   'Name of expense': 'Instanbull Pizza',
#   'Type of expense': 'Entertainment',
#   'Amount': 1364,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Saturday'},
#  {'Date': '01/07/2023',
#   'Month': 'July',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 40,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Saturday'},
#  {'Date': '02/07/2023',
#   'Month': 'July',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 320,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Sunday'},
#  {'Date': '02/07/2023',
#   'Month': 'July',
#   'Name of expense': 'Goodwill',
#   'Type of expense': 'Goodwill',
#   'Amount': 50,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Sunday'},
#  {'Date': '02/07/2023',
#   'Month': 'July',
#   'Name of expense': 'Vegetables',
#   'Type of expense': 'Food',
#   'Amount': 60,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Sunday'},
#  {'Date': '02/07/2023',
#   'Month': 'July',
#   'Name of expense': 'Minced Meat',
#   'Type of expense': 'Food',
#   'Amount': 200,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Sunday'},
#  {'Date': '02/07/2023',
#   'Month': 'July',
#   'Name of expense': 'Ngumu',
#   'Type of expense': 'Thrills',
#   'Amount': 10,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Sunday'},
#  {'Date': '02/07/2023',
#   'Month': 'July',
#   'Name of expense': 'Disparity',
#   'Type of expense': 'Disparity',
#   'Amount': 5,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Sunday'},
#  {'Date': '03/07/2023',
#   'Month': 'July',
#   'Name of expense': 'Medicine stock up',
#   'Type of expense': 'Medicine',
#   'Amount': 264,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Monday'},
#  {'Date': '03/07/2023',
#   'Month': 'July',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 210,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Monday'},
#  {'Date': '04/07/2023',
#   'Month': 'July',
#   'Name of expense': 'Fare',
#   'Type of expense': 'Transport',
#   'Amount': 180,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Tuesday'},
#  {'Date': '04/07/2023',
#   'Month': 'July',
#   'Name of expense': 'Credit',
#   'Type of expense': 'Credit',
#   'Amount': 500,
#   'Comments': '',
#   'Year': 2023,
#   'Day': 'Tuesday'},
#  ...]

# %%
import pandas as pd

# Convert the data to a DataFrame
df = pd.DataFrame(data)
df.head()
# Out:
#          Date Month     Name of expense Type of expense  Amount Comments  \
# 0  21/06/2022  June              Lotion     Accessories   195.0
# 1  21/06/2022  June             Smokies         Thrills    30.0
# 2  22/06/2022  June              Credit          Credit   100.0
# 3  22/06/2022  June  ID application fee       Utilities   100.0
# 4  22/06/2022  June                Eggs            Food    30.0
#
#    Year        Day
# 0  2022    Tuesday
# 1  2022    Tuesday
# 2  2022  Wednesday
# 3  2022  Wednesday
# 4  2022  Wednesday

# %% [markdown]
# **Data Validation**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3510 entries, 0 to 3509
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             3510 non-null   object
#  1   Month            3510 non-null   object
#  2   Name of expense  3510 non-null   object
#  3   Type of expense  3510 non-null   object
#  4   Amount           3510 non-null   float64
#  5   Comments         3510 non-null   object
#  6   Year             3510 non-null   int64
#  7   Day              3510 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 219.5+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y')
df.dtypes
# Out:
# Date               datetime64[ns]
# Month                      object
# Name of expense            object
# Type of expense            object
# Amount                    float64
# Comments                   object
# Year                        int64
# Day                        object
# dtype: object

# %%
df.astype({'Date': 'datetime'}).dtypes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.astype({'Date': 'datetime'}).dtypes
#
# File c:\Users\hp\Desktop\PROJECTS 2025\AutoExpense\venv\lib\site-packages\pandas\core\generic.py:6620, in NDFrame.astype(self, dtype, copy, errors)
#    6618 else:
#    6619     try:
# -> 6620         res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    6621     except ValueError as ex:
#    6622         ex.args = (
#    6623             f"{ex}: Error while type casting for column '{col_name}'",
#    6624         )
#
# File c:\Users\hp\Desktop\PROJECTS 2025\AutoExpense\venv\lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File c:\Users\hp\Desktop\PROJECTS 2025\AutoExpense\venv\lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File c:\Users\hp\Desktop\PROJECTS 2025\AutoExpense\venv\lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\hp\Desktop\PROJECTS 2025\AutoExpense\venv\lib\site-packages\pandas\core\internals\blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File c:\Users\hp\Desktop\PROJECTS 2025\AutoExpense\venv\lib\site-packages\pandas\core\dtypes\astype.py:231, in astype_array_safe(values, dtype, copy, errors)
#     225     msg = (
#     226         f"Expected an instance of {dtype.__name__}, "
#     227         "but got the class instead. Try instantiating 'dtype'."
#     228     )
#     229     raise TypeError(msg)
# --> 231 dtype = pandas_dtype(dtype)
#     232 if isinstance(dtype, NumpyEADtype):
#     233     # Ensure we don't end up with a NumpyExtensionArray
#     234     dtype = dtype.numpy_dtype
#
# File c:\Users\hp\Desktop\PROJECTS 2025\AutoExpense\venv\lib\site-packages\pandas\core\dtypes\common.py:1645, in pandas_dtype(dtype)
#    1640     with warnings.catch_warnings():
#    1641         # GH#51523 - Series.astype(np.integer) doesn't show
#    1642         # numpy deprecation warning of np.integer
#    1643         # Hence enabling DeprecationWarning
#    1644         warnings.simplefilter("always", DeprecationWarning)
# -> 1645         npdtype = np.dtype(dtype)
#    1646 except SyntaxError as err:
#    1647     # np.dtype uses `eval` which can raise SyntaxError
#    1648     raise TypeError(f"data type '{dtype}' not understood") from err
#
# TypeError: data type 'datetime' not understood
